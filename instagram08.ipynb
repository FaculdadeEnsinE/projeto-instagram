# %% [markdown]
# # Importar Biblioteca

# %%
import pandas as pd
import duckdb

# %% [markdown]
# # Conectar Duckdb to DataFrame Pandas

# %%
# conectar ao banco de dados duckdb
conn = duckdb.connect('./duckdb/instagram.duckdb')

# ler a tabela medias do duckdb
df = conn.execute("SELECT * FROM medias").fetchdf()

# desconectar do banco de dados
conn.close()

# %% [markdown]
# # DataFrame com Dados Resumidos

# %%
# Visualização das primeiras linhas do dataframe
display(df.head())
# Out:
#                   id                                            caption  \
# 0  18458023078097142  Fala forrozeiros do meu coração ❤️ ❤️ ❤️ \n\n🦎...
# 1  18057575402463021  Fala forrozeiros do meu coração ❤️ ❤️ ❤️ \n\n🦎...
# 2  18105873043883968                                                NaN
# 3  17849716308635070  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nVe...
# 4  17863397379580241  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nNe...
#
#   media_type  like_count  comments_count  \
# 0      VIDEO          23               2
# 1      VIDEO          33               5
# 2      VIDEO         136              16
# 3      VIDEO          13               3
# 4      VIDEO          29               2
#
#                                            media_url  \
# 0  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 1  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 2  https://instagram.fjdf2-2.fna.fbcdn.net/o1/v/t...
# 3  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 4  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
#
#                                      permalink           timestamp   username
# 0  https://www.instagram.com/reel/DWVDHyRDTZB/ 2026-03-26 01:17:06  djkalango
# 1  https://www.instagram.com/reel/DWVBLV_D0EE/ 2026-03-26 01:14:08  djkalango
# 2  https://www.instagram.com/reel/DV7GmGbjR4s/ 2026-03-15 23:27:35  djkalango
# 3  https://www.instagram.com/reel/DUi40ckDgkW/ 2026-02-09 17:15:01  djkalango
# 4  https://www.instagram.com/reel/DUbRNPJDg0E/ 2026-02-06 18:13:09  djkalango

# %%
# Exibir as últimas linhas
display(df.tail())
# Out:
#                      id                                            caption  \
# 1251  17975579599884261  Fala forrozeiros do meu coração, você sabe qua...
# 1252  18190994848232949  Faaaala forrozeiros do meu coração, preparados...
# 1253  17943442784281113  Faaaala forrozeiros do meu coração. 💃🕺\n\nÉ ju...
# 1254  17850840350866474  Faaaaala forrozeiros do meu coração, hoje o #t...
# 1255  18192478201211982  Fala forrozeiros do meu coração, você sabe que...
#
#           media_type  like_count  comments_count  \
# 1251           VIDEO          80               4
# 1252           IMAGE          77               2
# 1253           VIDEO          32               6
# 1254  CAROUSEL_ALBUM          45               2
# 1255           VIDEO          32               6
#
#                                               media_url  \
# 1251  https://instagram.fjdf2-2.fna.fbcdn.net/o1/v/t...
# 1252  https://scontent.cdninstagram.com/v/t51.82787-...
# 1253  https://instagram.fjdf2-2.fna.fbcdn.net/o1/v/t...
# 1254  https://scontent.cdninstagram.com/v/t51.82787-...
# 1255  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
#
#                                         permalink           timestamp  \
# 1251  https://www.instagram.com/reel/ClTz-nxsa2a/ 2022-11-23 16:09:28
# 1252     https://www.instagram.com/p/ClOW651rFbr/ 2022-11-21 13:16:42
# 1253  https://www.instagram.com/reel/ClJRDLwOPiQ/ 2022-11-19 13:51:01
# 1254     https://www.instagram.com/p/ClEB1NBLTcd/ 2022-11-17 13:00:01
# 1255  https://www.instagram.com/reel/ClB-wsxp7XH/ 2022-11-16 17:57:05
#
#        username
# 1251  djkalango
# 1252  djkalango
# 1253  djkalango
# 1254  djkalango
# 1255  djkalango

# %%
# Exibir uma amostra aleatória
display(df.sample(5))
# Out:
#                     id                                            caption  \
# 550  17848874874549189  Fala, Forrozeiros do meu coração! ❤️❤️❤️\n\nA ...
# 133  17883239410682547                                                NaN
# 521  17899057147235597  Sábado vai rolar a segunda edição do #forrio n...
# 79   17928069641447436  Forrozeiros do meu coração, do nosso workshop ...
# 507  17919269635223785  Um passarinho me contou que vem novidades por ...
#
#     media_type  like_count  comments_count  \
# 550      IMAGE          11               6
# 133      IMAGE          41               2
# 521      IMAGE          13               1
# 79       IMAGE          28               1
# 507      IMAGE          98               9
#
#                                              media_url  \
# 550  https://scontent.cdninstagram.com/v/t51.82787-...
# 133  https://scontent.cdninstagram.com/v/t51.82787-...
# 521  https://scontent.cdninstagram.com/v/t51.82787-...
# 79   https://scontent.cdninstagram.com/v/t51.82787-...
# 507  https://scontent.cdninstagram.com/v/t51.82787-...
#
#                                     permalink           timestamp   username
# 550  https://www.instagram.com/p/DP7wIA6DAH9/ 2025-10-18 02:21:19  djkalango
# 133  https://www.instagram.com/p/CDfKLfOBizq/ 2020-08-05 00:05:03  djkalango
# 521  https://www.instagram.com/p/Bmv1MBYhEqW/ 2018-08-21 16:18:17  djkalango
# 79   https://www.instagram.com/p/Cgwqy-puY7P/ 2022-08-02 14:27:35  djkalango
# 507  https://www.instagram.com/p/Bn_oKJuhpzk/ 2018-09-21 16:03:41  djkalango

# %% [markdown]
# # Descrição e Informações do Data Frame

# %%
# Quantidade total de linhas e colunas do dataframe
display(df.shape)
# Out:
# (1256, 9)

# %%
# Ver nomes das colunas
display(df.columns)
# Out:
# Index(['id', 'caption', 'media_type', 'like_count', 'comments_count',
#        'media_url', 'permalink', 'timestamp', 'username'],
#       dtype='str')

# %%
# Ver colunas e tipos
display(df.dtypes)
# Out:
# id                         int64
# caption                      str
# media_type                   str
# like_count                 int32
# comments_count             int32
# media_url                    str
# permalink                    str
# timestamp         datetime64[us]
# username                     str
# dtype: object

# %%
# Contar valores nulos por coluna
display(df.isnull().sum())
# Out:
# id                  0
# caption           138
# media_type          0
# like_count          0
# comments_count      0
# media_url           0
# permalink           0
# timestamp           0
# username            0
# dtype: int64

# %%
# Informações gerais: tipos de dados, memória, valores nulos
display(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1256 non-null   int64
#  1   caption         1118 non-null   str
#  2   media_type      1256 non-null   str
#  3   like_count      1256 non-null   int32
#  4   comments_count  1256 non-null   int32
#  5   media_url       1256 non-null   str
#  6   permalink       1256 non-null   str
#  7   timestamp       1256 non-null   datetime64[us]
#  8   username        1256 non-null   str
# dtypes: datetime64[us](1), int32(2), int64(1), str(5)
# memory usage: 78.6 KB
# None

# %%
# descicao geral do dataframe
display(df.describe())
# Out:
#                  id   like_count  comments_count                   timestamp
# count  1.256000e+03  1256.000000     1256.000000                        1256
# mean   1.794143e+16    34.988057        3.057325  2019-07-09 07:05:54.557324
# min    1.784155e+16     0.000000        0.000000         2012-10-21 13:57:17
# 25%    1.786445e+16    15.000000        0.000000  2017-07-24 18:13:24.250000
# 50%    1.791875e+16    28.000000        1.000000  2018-12-03 05:07:47.500000
# 75%    1.798967e+16    47.000000        2.000000  2022-05-24 04:12:31.750000
# max    1.853927e+16   216.000000      616.000000         2026-03-26 01:17:06
# std    1.010888e+14    28.997442       19.112455                         NaN

# %% [markdown]
# # Consultas SQL convertidas para Dataframa

# %%
# Quantidade total de mídias
total_medias = len(df)
display(f"Total de mídias: {total_medias}")
# Out:
# 'Total de mídias: 1256'

# %%
# Quantidade de mídias por tipo
medias_por_tipo = df.groupby("media_type").size().reset_index(name="count").sort_values("media_type")
display(medias_por_tipo)
# Out:
#        media_type  count
# 0  CAROUSEL_ALBUM     82
# 1           IMAGE    855
# 2           VIDEO    319

# %%
# Quantidade total de curtidas
total_likes = df["like_count"].sum()
display(f"Total de curtidas: {total_likes}")
# Out:
# 'Total de curtidas: 43945'

# %%
# Quantidade total de comentários
total_comments = df["comments_count"].sum()
display(f"Total de comentários: {total_comments}")
# Out:
# 'Total de comentários: 3840'

# %%
# Postagens com mais comentários (top 5)
top_comentadas = df.sort_values("comments_count", ascending=False).head(5)
display(top_comentadas[["id", "caption", "comments_count"]])
# Out:
#                     id                                            caption  \
# 292  18088544653934851  SORTEIOS REALIZADO\nganhadora foi @tatianapere...
# 23   18079243063899976  Sorteio realizado,  a sortuda foi @a.patydosca...
# 105  17857373438770240  Fala forrozeiros do meu coração, na última qui...
# 345  17922777829274176  SORTEIO\n\nDJ Kalango vai sortear 1 ingresso p...
# 302  18013049497169503  Para concorrer é fácil!!! Marque 2 amigos, cur...
#
#      comments_count
# 292             616
# 23              202
# 105              78
# 345              77
# 302              67

# %%
# Postagem mais antiga
mais_antiga = df.sort_values("timestamp", ascending=True).head(1)
display(mais_antiga[["id", "caption", "timestamp"]])
# Out:
#                      id                                            caption  \
# 1155  17842240510056037  Escolhendo o repertório da 2a Forrozada JF. E ...
#
#                timestamp
# 1155 2012-10-21 13:57:17

# %%
# Quantidade de postagens por ano, com o mais curtido e mais comentado
df["ANO"] = pd.to_datetime(df["timestamp"]).dt.year
postagens_por_ano = (
    # agrupamento por ano
    df.groupby("ANO")
      # o agg faz com que seja possível calcular várias estatísticas ao mesmo tempo
      .agg(
          # quantidade de postagens por ano
          QuantidadePost=("id", "count"),
          # post mais/max curtido por ano
          PostMaisCurtido=("like_count", "max"),
          # post mais/max comentado por ano
          PostMaisComentado=("comments_count", "max")
      )
      # resetar o index para transformar o ano em uma coluna normal
      .reset_index()
      # ordenar por ano
      .sort_values("ANO", ascending=False)
)
display(postagens_por_ano)
# Out:
#      ANO  QuantidadePost  PostMaisCurtido  PostMaisComentado
# 13  2026              12              136                 16
# 12  2025              80              129                616
# 11  2024              29              126                 28
# 10  2023              79              135                 29
# 9   2022             121              216                 78
# 8   2021               8              205                 35
# 7   2020              32              158                 56
# 6   2019             239              170                 77
# 5   2018             270              135                 22
# 4   2017             194              175                 35
# 3   2016              96               80                  7
# 2   2015              58               17                  2
# 1   2013              26                7                  1
# 0   2012              12                6                  1

# %% [markdown]
# # Gerar Gráficos

# %%
# importar matplotlib para visualização
import matplotlib.pyplot as plt

# %%
# Gráfico de postagens por ano
plt.figure(figsize=(10, 6))
plt.bar(postagens_por_ano["ANO"], postagens_por_ano["QuantidadePost"], color="skyblue")
plt.title("Quantidade de Postagens por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_ano["ANO"])
plt.grid(axis="y")
plt.show()

# %%
# Gráfico de linha com postagens por ano
plt.figure(figsize=(10, 6))
plt.plot(postagens_por_ano["ANO"], postagens_por_ano["QuantidadePost"], marker="o", color="orange")
plt.title("Quantidade de Postagens por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_ano["ANO"])
plt.grid()
plt.show()

# %%
# Gráfico de pizza -Quantidade de mídias por tipo
plt.figure(figsize=(10, 6))
# alteracao das cores do grafico de pizza
colors = ["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0", "#ffb3e6"]
plt.pie(medias_por_tipo["count"], labels=medias_por_tipo["media_type"], autopct="%1.1f%%", startangle=180, colors=colors)
plt.title("Distribuição de Mídias por Tipo")
plt.axis("equal")
plt.show()

# %% [markdown]
# # Abrir imagem pelo link media url

# %%
# DataFrame com imagem
df_imagem = df[df["media_type"] == "IMAGE"]
display(df_imagem.head())
# Out:
#                    id                                            caption  \
# 9   17927339199360802  Fala, Forrozeiros do meu coração! ❤️❤️❤️\n\nOl...
# 10  18070547321385363  Fala Forrozeiros do meu coração ❤️ ❤️ ❤️ \n\nP...
# 15  18076404635224700  Fala forrozeiros do meu coração! ❤️❤️❤️\n\n🎉 E...
# 22  18365085307088510  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nA ...
# 23  18079243063899976  Sorteio realizado,  a sortuda foi @a.patydosca...
#
#    media_type  like_count  comments_count  \
# 9       IMAGE          80              12
# 10      IMAGE          23               0
# 15      IMAGE          15               2
# 22      IMAGE          10               2
# 23      IMAGE          50             202
#
#                                             media_url  \
# 9   https://scontent.cdninstagram.com/v/t51.82787-...
# 10  https://scontent.cdninstagram.com/v/t51.82787-...
# 15  https://scontent.cdninstagram.com/v/t51.82787-...
# 22  https://scontent.cdninstagram.com/v/t51.82787-...
# 23  https://scontent.cdninstagram.com/v/t51.82787-...
#
#                                    permalink           timestamp   username  \
# 9   https://www.instagram.com/p/DUGcTW4jiCZ/ 2026-01-29 16:05:20  djkalango
# 10  https://www.instagram.com/p/DTRAQRijkje/ 2026-01-08 22:00:30  djkalango
# 15  https://www.instagram.com/p/DRxNKaojka-/ 2025-12-02 17:06:12  djkalango
# 22  https://www.instagram.com/p/DRfHYmXjsz5/ 2025-11-25 16:29:23  djkalango
# 23  https://www.instagram.com/p/DRW8nj7Dk6V/ 2025-11-22 12:21:23  djkalango
#
#      ANO
# 9   2026
# 10  2026
# 15  2025
# 22  2025
# 23  2025
# 855

# %%
# Out:
# 687

# %%
import requests
from PIL import Image
from io import BytesIO

import random

# Gerar um número inteiro aleatório entre 0 e o número de linhas do dataframe de imagens - 1
random_integer = random.randint(0, df_imagem.shape[0] - 1)

# URL da media / imagem
media_url  = df_imagem['media_url'].iloc[random_integer]
media_type = df_imagem['media_type'].iloc[random_integer]
caption     = df_imagem['caption'].iloc[random_integer]
print("URL da imagem:", media_url)
print("Tipo da mídia:", media_type)
print("Indice da imagem:", random_integer)
print("Legenda:", caption)

if media_type != "IMAGE":
    print("A mídia não é uma imagem. Tipo:", media_type)
else:
    # Faz a requisição HTTP
    response = requests.get(media_url)

    # Verifica se deu certo
    if response.status_code == 200:
        # Converte o conteúdo em objeto de imagem
        img = Image.open(BytesIO(response.content))
        img.show()  # abre no visualizador padrão
    else:
        print("Erro ao baixar imagem:", response.status_code)
# Out:
# URL da imagem: https://scontent.cdninstagram.com/v/t51.82787-15/624064081_18363366571207954_5737543191945758860_n.jpg?stp=dst-jpg_e35_tt6&_nc_cat=106&ccb=7-5&_nc_sid=18de74&efg=eyJlZmdfdGFnIjoiRkVFRC5iZXN0X2ltYWdlX3VybGdlbi5DMyJ9&_nc_ohc=JwwNI7DfA_QQ7kNvwEW2gpC&_nc_oc=AdolxC1OlmEDuz-5AU5XWsW4P1XCKhHT-3b1DWxjR4ozGyA6N9G-h9hgq9_nku4YIUQ&_nc_zt=23&_nc_ht=scontent.cdninstagram.com&edm=ANo9K5cEAAAA&_nc_gid=mfkb17tvZ-HPmtsg4Ivk2A&_nc_tpa=Q5bMBQFStj7ru544MTtUd3TZ1A6YLZjPshSWPHH_PgncPLyHxvh2c0Xt_qzAZ_nR0JKg1UizTBR0s0kN2Q&oh=00_AfxHZ1w2blUE2lHpP9ZCnvlUyqNHfGYPxvwSQNQOiXbypg&oe=69CB825B
# Tipo da mídia: IMAGE
# Indice da imagem: 283
# Legenda: Domingo tem @djkalango no @jfburgerfest.
# Hoje fui lá degustar alguns sandubas.
# #forró #forrójf #pédeserra #pédeserrajf #djkalango #djkalangojf #djforró #vinil #kalangoforró #kalangodj #kalangojf #kalango #forróvinil #djvinil #jfburgerfest #jfburguerfest #jfburgerfest2018
