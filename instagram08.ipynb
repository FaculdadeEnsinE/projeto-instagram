# %% [markdown]
# # Importar Biblioteca

# %%
import pandas as pd
import duckdb

# %% [markdown]
# # Conectar Duckdb to DataFrame Pandas

# %%
# conectar ao banco de dados duckdb
conn = duckdb.connect('./duckdb/instagram.duckdb')

# ler a tabela medias do duckdb
df = conn.execute("SELECT * FROM medias").fetchdf()

# desconectar do banco de dados
conn.close()

# %% [markdown]
# # DataFrame com Dados Resumidos

# %%
# Visualização das primeiras linhas do dataframe
display(df.head())
# Out:
#                   id                                            caption  \
# 0  18105873043883968                                                NaN
# 1  17849716308635070  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nVe...
# 2  17863397379580241  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nNe...
# 3  18086865482140239  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nHo...
# 4  18020943137802575  Fala forrozeiros do meu coração ❤️ ❤️ ❤️ \n\nG...
#
#        media_type  like_count  comments_count  \
# 0           VIDEO         130              16
# 1           VIDEO          13               3
# 2           VIDEO          29               2
# 3  CAROUSEL_ALBUM          39               4
# 4           VIDEO          41               8
#
#                                            media_url  \
# 0  https://instagram.fjdf2-2.fna.fbcdn.net/o1/v/t...
# 1  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 2  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 3  https://scontent.cdninstagram.com/v/t51.82787-...
# 4  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
#
#                                      permalink           timestamp   username
# 0  https://www.instagram.com/reel/DV7GmGbjR4s/ 2026-03-15 23:27:35  djkalango
# 1  https://www.instagram.com/reel/DUi40ckDgkW/ 2026-02-09 17:15:01  djkalango
# 2  https://www.instagram.com/reel/DUbRNPJDg0E/ 2026-02-06 18:13:09  djkalango
# 3     https://www.instagram.com/p/DUYs2kVjowR/ 2026-02-05 18:16:17  djkalango
# 4  https://www.instagram.com/reel/DUWDZ4mDpFW/ 2026-02-04 17:41:09  djkalango

# %%
# Exibir as últimas linhas
display(df.tail())
# Out:
#                      id                                            caption  \
# 1249  17943442784281113  Faaaala forrozeiros do meu coração. 💃🕺\n\nÉ ju...
# 1250  17850840350866474  Faaaaala forrozeiros do meu coração, hoje o #t...
# 1251  18192478201211982  Fala forrozeiros do meu coração, você sabe que...
# 1252  17952967982254460  Faaala forrozeiros do meu coração. 🕺💃\n\nTodos...
# 1253  18228569416154012  Faaaala forrozeiros do meu coração. 💃🕺\n\nO #K...
#
#           media_type  like_count  comments_count  \
# 1249           VIDEO          32               6
# 1250  CAROUSEL_ALBUM          45               2
# 1251           VIDEO          32               6
# 1252           IMAGE          50               0
# 1253           VIDEO          44               6
#
#                                               media_url  \
# 1249  https://instagram.fjdf2-2.fna.fbcdn.net/o1/v/t...
# 1250  https://scontent.cdninstagram.com/v/t51.82787-...
# 1251  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 1252  https://scontent.cdninstagram.com/v/t51.82787-...
# 1253  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
#
#                                         permalink           timestamp  \
# 1249  https://www.instagram.com/reel/ClJRDLwOPiQ/ 2022-11-19 13:51:01
# 1250     https://www.instagram.com/p/ClEB1NBLTcd/ 2022-11-17 13:00:01
# 1251  https://www.instagram.com/reel/ClB-wsxp7XH/ 2022-11-16 17:57:05
# 1252     https://www.instagram.com/p/Ck8dsf_rtAB/ 2022-11-14 14:29:34
# 1253  https://www.instagram.com/reel/Ck3bNlODnMt/ 2022-11-12 15:33:27
#
#        username
# 1249  djkalango
# 1250  djkalango
# 1251  djkalango
# 1252  djkalango
# 1253  djkalango

# %%
# Exibir uma amostra aleatória
display(df.sample(5))
# Out:
#                      id                                            caption  \
# 88    17990089183476317  Faaala forrozeiros do meu coração, olha a agen...
# 678   17928299398023846  Domingo o bicho vai pegar.\n#domingueiradeforr...
# 1108  18286520443160773  Fala Forrozeiros do meu coração ❤️ ❤️ ❤️ \n\nH...
# 783   17886454594071408  #rodadesanfona \n#djkalango #forró #forrójf \n...
# 894   17876726389032408       #djkalango #forró #vinil #forrodorei #galpão
#
#      media_type  like_count  comments_count  \
# 88        IMAGE          92               4
# 678       IMAGE          16               2
# 1108      VIDEO          26               0
# 783       IMAGE          14               0
# 894       IMAGE          20               2
#
#                                               media_url  \
# 88    https://scontent.cdninstagram.com/v/t51.82787-...
# 678   https://scontent.cdninstagram.com/v/t51.82787-...
# 1108  https://instagram.fjdf7-1.fna.fbcdn.net/o1/v/t...
# 783   https://scontent.cdninstagram.com/v/t51.82787-...
# 894   https://scontent.cdninstagram.com/v/t51.82787-...
#
#                                         permalink           timestamp  \
# 88       https://www.instagram.com/p/CgLAZSArV1I/ 2022-07-18 23:25:11
# 678      https://www.instagram.com/p/Bf19oEMlagP/ 2018-03-03 01:47:42
# 1108  https://www.instagram.com/reel/C558-DHrYK2/ 2024-04-18 14:07:10
# 783      https://www.instagram.com/p/BXX9Qp-lpLd/ 2017-08-04 13:56:09
# 894      https://www.instagram.com/p/BSmw0DsAzc6/ 2017-04-08 01:19:01
#
#        username
# 88    djkalango
# 678   djkalango
# 1108  djkalango
# 783   djkalango
# 894   djkalango

# %% [markdown]
# # Descrição e Informações do Data Frame

# %%
# Quantidade total de linhas e colunas do dataframe
display(df.shape)
# Out:
# (1254, 9)

# %%
# Ver nomes das colunas
display(df.columns)
# Out:
# Index(['id', 'caption', 'media_type', 'like_count', 'comments_count',
#        'media_url', 'permalink', 'timestamp', 'username'],
#       dtype='str')

# %%
# Ver colunas e tipos
display(df.dtypes)
# Out:
# id                         int64
# caption                      str
# media_type                   str
# like_count                 int32
# comments_count             int32
# media_url                    str
# permalink                    str
# timestamp         datetime64[us]
# username                     str
# dtype: object

# %%
# Contar valores nulos por coluna
display(df.isnull().sum())
# Out:
# id                  0
# caption           138
# media_type          0
# like_count          0
# comments_count      0
# media_url           0
# permalink           0
# timestamp           0
# username            0
# dtype: int64

# %%
# Informações gerais: tipos de dados, memória, valores nulos
display(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1254 non-null   int64
#  1   caption         1116 non-null   str
#  2   media_type      1254 non-null   str
#  3   like_count      1254 non-null   int32
#  4   comments_count  1254 non-null   int32
#  5   media_url       1254 non-null   str
#  6   permalink       1254 non-null   str
#  7   timestamp       1254 non-null   datetime64[us]
#  8   username        1254 non-null   str
# dtypes: datetime64[us](1), int32(2), int64(1), str(5)
# memory usage: 78.5 KB
# None

# %%
# descicao geral do dataframe
display(df.describe())
# Out:
#                  id   like_count  comments_count                   timestamp
# count  1.254000e+03  1254.000000     1254.000000                        1254
# mean   1.794093e+16    34.992026        3.056619  2019-07-05 09:15:04.824561
# min    1.784155e+16     0.000000        0.000000         2012-10-21 13:57:17
# 25%    1.786441e+16    15.000000        0.000000  2017-07-24 02:40:50.750000
# 50%    1.791871e+16    28.000000        1.000000  2018-12-02 09:39:40.500000
# 75%    1.798883e+16    47.000000        2.000000  2022-05-04 14:23:38.500000
# max    1.853927e+16   215.000000      616.000000         2026-03-15 23:27:35
# std    1.000563e+14    28.997233       19.127601                         NaN

# %% [markdown]
# # Consultas SQL convertidas para Dataframa

# %%
# Quantidade total de mídias
total_medias = len(df)
display(f"Total de mídias: {total_medias}")
# Out:
# 'Total de mídias: 1254'

# %%
# Quantidade de mídias por tipo
medias_por_tipo = df.groupby("media_type").size().reset_index(name="count").sort_values("media_type")
display(medias_por_tipo)
# Out:
#        media_type  count
# 0  CAROUSEL_ALBUM     82
# 1           IMAGE    855
# 2           VIDEO    317

# %%
# Quantidade total de curtidas
total_likes = df["like_count"].sum()
display(f"Total de curtidas: {total_likes}")
# Out:
# 'Total de curtidas: 43880'

# %%
# Quantidade total de comentários
total_comments = df["comments_count"].sum()
display(f"Total de comentários: {total_comments}")
# Out:
# 'Total de comentários: 3833'

# %%
# Postagens com mais comentários (top 5)
top_comentadas = df.sort_values("comments_count", ascending=False).head(5)
display(top_comentadas[["id", "caption", "comments_count"]])
# Out:
#                     id                                            caption  \
# 290  18088544653934851  SORTEIOS REALIZADO\nganhadora foi @tatianapere...
# 21   18079243063899976  Sorteio realizado,  a sortuda foi @a.patydosca...
# 103  17857373438770240  Fala forrozeiros do meu coração, na última qui...
# 343  17922777829274176  SORTEIO\n\nDJ Kalango vai sortear 1 ingresso p...
# 300  18013049497169503  Para concorrer é fácil!!! Marque 2 amigos, cur...
#
#      comments_count
# 290             616
# 21              202
# 103              78
# 343              77
# 300              67

# %%
# Postagem mais antiga
mais_antiga = df.sort_values("timestamp", ascending=True).head(1)
display(mais_antiga[["id", "caption", "timestamp"]])
# Out:
#                      id                                            caption  \
# 1153  17842240510056037  Escolhendo o repertório da 2a Forrozada JF. E ...
#
#                timestamp
# 1153 2012-10-21 13:57:17

# %%
# Quantidade de postagens por ano, com o mais curtido e mais comentado
df["ANO"] = pd.to_datetime(df["timestamp"]).dt.year
postagens_por_ano = (
    # agrupamento por ano
    df.groupby("ANO")
      # o agg faz com que seja possível calcular várias estatísticas ao mesmo tempo
      .agg(
          # quantidade de postagens por ano
          QuantidadePost=("id", "count"),
          # post mais/max curtido por ano
          PostMaisCurtido=("like_count", "max"),
          # post mais/max comentado por ano
          PostMaisComentado=("comments_count", "max")
      )
      # resetar o index para transformar o ano em uma coluna normal
      .reset_index()
      # ordenar por ano
      .sort_values("ANO", ascending=False)
)
display(postagens_por_ano)
# Out:
#      ANO  QuantidadePost  PostMaisCurtido  PostMaisComentado
# 13  2026              10              130                 16
# 12  2025              80              129                616
# 11  2024              29              126                 28
# 10  2023              79              135                 29
# 9   2022             121              215                 78
# 8   2021               8              205                 35
# 7   2020              32              158                 56
# 6   2019             239              170                 77
# 5   2018             270              135                 22
# 4   2017             194              175                 35
# 3   2016              96               80                  7
# 2   2015              58               17                  2
# 1   2013              26                7                  1
# 0   2012              12                6                  1

# %% [markdown]
# # Gerar Gráficos

# %%
# importar matplotlib para visualização
import matplotlib.pyplot as plt

# %%
# Gráfico de postagens por ano
plt.figure(figsize=(10, 6))
plt.bar(postagens_por_ano["ANO"], postagens_por_ano["QuantidadePost"], color="skyblue")
plt.title("Quantidade de Postagens por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_ano["ANO"])
plt.grid(axis="y")
plt.show()

# %%
# Gráfico de linha com postagens por ano
plt.figure(figsize=(10, 6))
plt.plot(postagens_por_ano["ANO"], postagens_por_ano["QuantidadePost"], marker="o", color="orange")
plt.title("Quantidade de Postagens por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_ano["ANO"])
plt.grid()
plt.show()

# %%
# Gráfico de pizza -Quantidade de mídias por tipo
plt.figure(figsize=(10, 6))
# alteracao das cores do grafico de pizza
colors = ["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0", "#ffb3e6"]
plt.pie(medias_por_tipo["count"], labels=medias_por_tipo["media_type"], autopct="%1.1f%%", startangle=180, colors=colors)
plt.title("Distribuição de Mídias por Tipo")
plt.axis("equal")
plt.show()

# %% [markdown]
# # Abrir imagem pelo link media url

# %%
# DataFrame com imagem
df_imagem = df[df["media_type"] == "IMAGE"]
display(df_imagem.head())
# Out:
#                    id                                            caption  \
# 7   17927339199360802  Fala, Forrozeiros do meu coração! ❤️❤️❤️\n\nOl...
# 8   18070547321385363  Fala Forrozeiros do meu coração ❤️ ❤️ ❤️ \n\nP...
# 13  18076404635224700  Fala forrozeiros do meu coração! ❤️❤️❤️\n\n🎉 E...
# 20  18365085307088510  Fala forrozeiros do meu coração! ❤️❤️❤️ \n\nA ...
# 21  18079243063899976  Sorteio realizado,  a sortuda foi @a.patydosca...
#
#    media_type  like_count  comments_count  \
# 7       IMAGE          80              12
# 8       IMAGE          23               0
# 13      IMAGE          15               2
# 20      IMAGE          10               2
# 21      IMAGE          50             202
#
#                                             media_url  \
# 7   https://scontent.cdninstagram.com/v/t51.82787-...
# 8   https://scontent.cdninstagram.com/v/t51.82787-...
# 13  https://scontent.cdninstagram.com/v/t51.82787-...
# 20  https://scontent.cdninstagram.com/v/t51.82787-...
# 21  https://scontent.cdninstagram.com/v/t51.82787-...
#
#                                    permalink           timestamp   username  \
# 7   https://www.instagram.com/p/DUGcTW4jiCZ/ 2026-01-29 16:05:20  djkalango
# 8   https://www.instagram.com/p/DTRAQRijkje/ 2026-01-08 22:00:30  djkalango
# 13  https://www.instagram.com/p/DRxNKaojka-/ 2025-12-02 17:06:12  djkalango
# 20  https://www.instagram.com/p/DRfHYmXjsz5/ 2025-11-25 16:29:23  djkalango
# 21  https://www.instagram.com/p/DRW8nj7Dk6V/ 2025-11-22 12:21:23  djkalango
#
#      ANO
# 7   2026
# 8   2026
# 13  2025
# 20  2025
# 21  2025

# %%
import requests
from PIL import Image
from io import BytesIO

# URL da media
# media_url = df_imagem['media_url'][0]
# media_type = df_imagem['media_type'][0]

# URL da imagem
# media_url  = df_imagem[df_imagem['media_type'] == 'IMAGE']['media_url'].iloc[10]
# media_type = df_imagem[df_imagem['media_type'] == 'IMAGE']['media_type'].iloc[10]

media_url  = df_imagem['media_url'].iloc[10]
media_type = df_imagem['media_type'].iloc[10]
print("URL da imagem:", media_url)
print("Tipo da mídia:", media_type)
if media_type != "IMAGE":
    print("A mídia não é uma imagem. Tipo:", media_type)
else:
    # Faz a requisição HTTP
    response = requests.get(media_url)

    # Verifica se deu certo
    if response.status_code == 200:
        # Converte o conteúdo em objeto de imagem
        img = Image.open(BytesIO(response.content))
        img.show()  # abre no visualizador padrão
    else:
        print("Erro ao baixar imagem:", response.status_code)
# Out:
# URL da imagem: https://scontent.cdninstagram.com/v/t51.82787-15/623835598_18081024283986377_1220375306646802960_n.jpg?stp=dst-jpg_e35_tt6&_nc_cat=103&ccb=7-5&_nc_sid=18de74&efg=eyJlZmdfdGFnIjoiRkVFRC5iZXN0X2ltYWdlX3VybGdlbi5DMyJ9&_nc_ohc=XfDVvGwKp1wQ7kNvwFpKmJX&_nc_oc=AdpfPFibXxDNJbsIyZKAiR1cyc-iisSr71gdMqCtxU-unaYsY-isWRFXrNC8AtvSsUXO2-Wmq3d2o6j8E4nRSsN_&_nc_zt=23&_nc_ht=scontent.cdninstagram.com&edm=ANo9K5cEAAAA&_nc_gid=rFyvl979_QNTawqPMv4pEw&_nc_tpa=Q5bMBQE7yu3exCGVgdO3jTYDYguv7KuNCwqjfNCEvgNOGtV1pJpuSj6VGSXoqucVJpgPNY2PL7NZlZ74Qg&oh=00_AfwpnSzSuumcy3EHmi2c75NZe4WpbIxbce3O0ANXrA7TLg&oe=69C153D6
# Tipo da mídia: IMAGE
# Erro ao baixar imagem: 403
