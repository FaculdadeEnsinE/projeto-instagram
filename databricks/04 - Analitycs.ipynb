# %% [markdown]
# # Importar Biblioteca

# %%
import pandas as pd

# Display the last 5 rows (requires a monotonic column or reverse order)
from pyspark.sql.functions import monotonically_increasing_id

# %% [markdown]
# # Conectar Duckdb to DataFrame Pandas

# %%
df = spark.read.table("instagram.gold.post")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>caption</th><th>media_type</th><th>like_count</th><th>comments_count</th><th>media_url</th><th>permalink</th><th>timestamp</th><th>thumbnail_url</th><th>username</th><th>children.data</th></tr></thead><tbody><tr><td>18080991158630678</td><td>Fala Forrozeiros do meu coração
#
# Nos últimos dias, tenho encontrado com alguns amigos e tem me perguntado, onde tem agenda do forró.
#
# Porque o @forrojf está desativado.
#
# Então aqui vai um recado:
#
# Estou voltando com a agenda no @forrojf e eu vou utilizar essa agenda para divulgar no programa de rádio no Nosso Forró da 93FM @radio93jf
#
# Então a partir de hoje começa a fazer essa divulgação.
#
# Vou colocar na legenda como que vai funcionar mas por enquanto lá vai:
#
# Terça-feira, 21/04, a partir das 18 horas, Resenha de Forró na Praça da Estação. Serão 5 DJs @djmarceloviajante fazendo um forrozinho lá das 6h até às 10h da noite e se bobear, DJ Kalango vai colar lá também, mas não tem DJ Kalango na programação.
#
# Quinta-feira, 23/04, tem @soparentforreggae com aquele projeto Só Pra Gente, projeto que eles tão fazendo um forrozinho intimista, lá no Boteco do Mar, no Salvaterra.
#
# Agora vai uma aqui na quinta-feira, eu fiquei sabendo, não me flyer, não sei se é verdade, mas ela vai fiquei sabendo que vai ter @forrozeta_jf na praça do Santa Cruz shopping. Então se for verdade, em breve vai ter uma arte por aqui, se for mentira, vocês me ignorem, ó esquece isso aí.
#
# Então vamos continuar, no dia 25/04, no sábado, vai ter @triosoforro no Mercado Municipal a partir das 18:30.
#
# No dia 26/04, domingão, para encerrar essa semana, vai ter @forrobodelas lá no Fire Hall, antigo Na Garganta. Se você não sabe onde é, é ali na subidinha da Rio Branco no Manoel Honório, indo para garganta, antigo Na Garganta.
# As atrações do Forróbodelas são: @forrodamonike , @djcaboclosp e DJ Kalango.
#
# Antes de terminar, o mês de maio, já está aí batendo na porta e já tem dois eventos marcado com DJ Kalango:
# - 17/05 - Shot de Forró no @shotcaferockpub a partir das 9h da manhã loucura forró de manhã.
# - 24/05 - Encontro de Forró, na Rua ABHerta do Moinho.
#
# Vamos dançar forró.</td><td>VIDEO</td><td>51</td><td>12</td><td>https://scontent-ord5-2.cdninstagram.com/o1/v/t2/f2/m86/AQO9HUl7jed4CtURv3p4oicfiE78ODiPbNTtg9nKU6f-7Cnn3UeB6eBPRWcmQJN7dKqdXvGxL6EWSTSj8YcmZ3oySpYhnyNl_UAY0UE.mp4?_nc_cat=102&_nc_sid=5e9851&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_ohc=zTVDjMIwGW4Q7kNvwEvNUzK&efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVz
# File /databricks/python_shell/lib/dbruntime/display.py:161, in Display.display(self, input, *args, **kwargs)
#     159         self.add_custom_display_data("table", input._jdf)
#     160 elif isinstance(input, list) and len(input) > 0:
# --> 161     self.display(self.sparkSession.createDataFrame(input))
#     162 elif type(input).__module__ == 'pandas.core.frame' and type(input).__name__ == 'DataFrame':
#     163     self.display(self.sparkSession.createDataFrame(input))
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/session.py:665, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     660         _num_cols = len(_cols)
#     662     if _has_nulltype(_schema):
#     663         # For cases like createDataFrame([("Alice", None, 80.1)], schema)
#     664         # we can not infer the schema from the data itself.
# --> 665         raise PySparkValueError(
#     666             error_class="CANNOT_DETERMINE_TYPE", message_parameters={}
#     667         )
#     669 from pyspark.sql.connect.conversion import LocalDataToArrowConversion
#     671 # Spark Connect will try its best to build the Arrow table with the
#     672 # inferred schema in the client side, and then rename the columns and
#     673 # cast the datatypes in the server side.
#
# PySparkValueError: [CANNOT_DETERMINE_TYPE] Some of types cannot be determined after inferring.

# %%
# Exibir uma amostra aleatória
display(df.limit(5))

# %% [markdown]
# # Descrição e Informações do Data Frame

# %%
# Quantidade total de linhas e colunas do dataframe
num_rows = df.count()
num_cols = len(df.columns)
display(f"Total de linhas: {num_rows}, Total de colunas: {num_cols}")

# %%
# Ver nomes das colunas
display(df.columns)

# %%
# Ver colunas e tipos
display(df.dtypes)

# %%
# Contar valores nulos por coluna
from pyspark.sql.functions import col, sum as spark_sum, when

null_counts = df.select([spark_sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df.columns])
display(null_counts)

# %%
# Informações gerais: tipos de dados, memória, valores nulos
df.printSchema(); df.describe().show()

# %%
# descicao geral do dataframe
display(df.describe())

# %% [markdown]
# # Consultas SQL convertidas para Dataframa

# %%
# Quantidade total de mídias
#total_medias = len(df)
#display(f"Total de mídias: {total_medias}")

# %%
# Quantidade de mídias por tipo
medias_por_tipo = df.groupby("media_type").size().reset_index(name="count").sort_values("media_type")
display(medias_por_tipo)

# %%
# Quantidade total de curtidas
total_likes = df["like_count"].sum()
display(f"Total de curtidas: {total_likes}")

# %%
# Quantidade total de comentários
total_comments = df["comments_count"].sum()
display(f"Total de comentários: {total_comments}")

# %%
# Postagens com mais comentários (top 5)
top_comentadas = df.sort_values("comments_count", ascending=False).head(5)
display(top_comentadas[["id", "caption", "comments_count"]])

# %%
# Postagem mais antiga
mais_antiga = df.sort_values("timestamp", ascending=True).head(1)
display(mais_antiga[["id", "caption", "timestamp"]])

# %%
# Quantidade de postagens por ano, com o mais curtido e mais comentado
df["ANO"] = pd.to_datetime(df["timestamp"]).dt.year
postagens_por_ano = (
    # agrupamento por ano
    df.groupby("ANO")
      # o agg faz com que seja possível calcular várias estatísticas ao mesmo tempo
      .agg(
          # quantidade de postagens por ano
          QuantidadePost=("id", "count"),
          # post mais/max curtido por ano
          PostMaisCurtido=("like_count", "max"),
          # post mais/max comentado por ano
          PostMaisComentado=("comments_count", "max")
      )
      # resetar o index para transformar o ano em uma coluna normal
      .reset_index()
      # ordenar por ano
      .sort_values("ANO", ascending=False)
)
display(postagens_por_ano)

# %% [markdown]
# # Gerar Gráficos

# %%
# importar matplotlib para visualização
import matplotlib.pyplot as plt

# %%
# Gráfico de postagens por ano
plt.figure(figsize=(10, 6))
plt.bar(postagens_por_ano["ANO"], postagens_por_ano["QuantidadePost"], color="skyblue")
plt.title("Quantidade de Postagens por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_ano["ANO"])
plt.grid(axis="y")
plt.show()

# %%
# Gráfico de linha com postagens por ano
plt.figure(figsize=(10, 6))
plt.plot(postagens_por_ano["ANO"], postagens_por_ano["QuantidadePost"], marker="o", color="orange")
plt.title("Quantidade de Postagens por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_ano["ANO"])
plt.grid()
plt.show()

# %%
# Gráfico de pizza -Quantidade de mídias por tipo
plt.figure(figsize=(10, 6))
# alteracao das cores do grafico de pizza
colors = ["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0", "#ffb3e6"]
plt.pie(medias_por_tipo["count"], labels=medias_por_tipo["media_type"], autopct="%1.1f%%", startangle=180, colors=colors)
plt.title("Distribuição de Mídias por Tipo")
plt.axis("equal")
plt.show()

# %% [markdown]
# # Abrir imagem pelo link media url

# %%
# DataFrame com imagem
df_imagem = df[df["media_type"] == "IMAGE"]
display(df_imagem.head())

# %%
import requests
from PIL import Image
from io import BytesIO

import random

# Gerar um número inteiro aleatório entre 0 e o número de linhas do dataframe de imagens - 1
random_integer = random.randint(0, df_imagem.shape[0] - 1)

# URL da media / imagem
media_url  = df_imagem['media_url'].iloc[random_integer]
media_type = df_imagem['media_type'].iloc[random_integer]
caption     = df_imagem['caption'].iloc[random_integer]
print("URL da imagem:", media_url)
print("Tipo da mídia:", media_type)
print("Indice da imagem:", random_integer)
print("Legenda:", caption)

if media_type != "IMAGE":
    print("A mídia não é uma imagem. Tipo:", media_type)
else:
    # Faz a requisição HTTP
    response = requests.get(media_url)

    # Verifica se deu certo
    if response.status_code == 200:
        # Converte o conteúdo em objeto de imagem
        img = Image.open(BytesIO(response.content))
        img.show()  # abre no visualizador padrão
    else:
        print("Erro ao baixar imagem:", response.status_code)

# %% [markdown]
# # novos testes

# %%
# Quantidade de postagens por anomes, com o mais curtido e mais comentado
df["MES"] = pd.to_datetime(df["timestamp"]).dt.month
df["DIA"] = pd.to_datetime(df["timestamp"]).dt.day
df["HORA"] = pd.to_datetime(df["timestamp"]).dt.hour
df["MINUTO"] = pd.to_datetime(df["timestamp"]).dt.minute
df["DIA_SEMANA"] = pd.to_datetime(df["timestamp"]).dt.day_name()
df["ANOMES"] = df["ANO"].astype(str) + "-" + df["MES"].astype(str).str.zfill(2)

# %%
postagens_por_anomes = (
    # agrupamento por anomes
    df[df["ANO"] == 2018]
      .groupby(["ANOMES"])
      # o agg faz com que seja possível calcular várias estatísticas ao mesmo tempo
      .agg(
          # quantidade de postagens por ano
          QuantidadePost=("id", "count"),
          # post mais/max curtido por ano
          PostMaisCurtido=("like_count", "max"),
          # post mais/max comentado por ano
          PostMaisComentado=("comments_count", "max")
      )
      # resetar o index para transformar o ano em uma coluna normal
      .reset_index()
      # ordenar por ano
      .sort_values(["ANOMES"], ascending=False)
)
display(postagens_por_anomes)

# %%
# Gráfico de linha com postagens por postagens_por_anomes
plt.figure(figsize=(10, 6))
plt.plot(postagens_por_anomes["ANOMES"], postagens_por_anomes["QuantidadePost"], marker="o", color="orange")
plt.title("Quantidade de Postagens por Ano/Mês")
plt.xlabel("Ano/Mês")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_anomes["ANOMES"], rotation=90)
plt.grid()
plt.show()

# %%
postagens_por_mes = (
    # agrupamento por mes
    df.groupby(["MES"])
      # o agg faz com que seja possível calcular várias estatísticas ao mesmo tempo
      .agg(
          # quantidade de postagens por ano
          QuantidadePost=("id", "count"),
          # post mais/max curtido por ano
          PostMaisCurtido=("like_count", "max"),
          # post mais/max comentado por ano
          PostMaisComentado=("comments_count", "max")
      )
      # resetar o index para transformar o ano em uma coluna normal
      .reset_index()
      # ordenar por ano
      .sort_values(["MES"], ascending=False)
)
display(postagens_por_mes)

# %%
# Gráfico de linha com postagens por postagens_por_mes
plt.figure(figsize=(10, 6))
plt.plot(postagens_por_mes["MES"], postagens_por_mes["QuantidadePost"], marker="o", color="red")
plt.title("Quantidade de Postagens por Mês")
plt.xlabel("Mês")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_mes["MES"], rotation=90)
plt.grid()
plt.show()

# %%
postagens_por_diasemana = (
    # agrupamento por dia da semana
    df.groupby("DIA_SEMANA")
      # o agg faz com que seja possível calcular várias estatísticas ao mesmo tempo
      .agg(
          # quantidade de postagens por ano
          QuantidadePost=("id", "count"),
          # post mais/max curtido por ano
          PostMaisCurtido=("like_count", "max"),
          # post mais/max comentado por ano
          PostMaisComentado=("comments_count", "max")
      )
      # resetar o index para transformar o ano em uma coluna normal
      .reset_index()
      # ordenar por dia da semana
      .sort_values("DIA_SEMANA", ascending=False)
)
display(postagens_por_diasemana)

# %%
# Gráfico de postagens por dia da semana
plt.figure(figsize=(10, 6))
plt.bar(postagens_por_diasemana["DIA_SEMANA"], postagens_por_diasemana["QuantidadePost"], color="skyblue")
plt.title("Quantidade de Postagens por Dia da Semana")
plt.xlabel("Dia da Semana")
plt.ylabel("Quantidade de Postagens")
plt.xticks(postagens_por_diasemana["DIA_SEMANA"])
plt.grid(axis="y")
plt.show()
